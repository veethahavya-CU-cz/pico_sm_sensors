# %%
import pandas as pd

# %%
sm = pd.read_csv('./sm.csv', header=None, sep = '; ')
sm
# Out:
# C:\Users\Veethahavya\AppData\Local\Temp\ipykernel_8220\3369065509.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   sm = pd.read_csv('./sm.csv', header=None, sep = '; ')
#          0         1
# 0        0  0.190111
# 1        0  0.180439
# 2        1  0.180282
# 3        2  0.180124
# 4        0  0.186806
# ...    ...       ...
# 5651  4294  0.441051
# 5652  4295  0.441053
# 5653  4296  0.441830
# 5654  4296  0.441215
# 5655  4297  0.441017
#
# [5656 rows x 2 columns]

# %%
sm[1].plot(figsize=(17.5, 5))
# Out:
# <Axes: >

# %%
sm[0]
# Out:
# 0          0; 0.1901106
# 1          0; 0.1804385
# 2          1; 0.1802823
# 3          2; 0.1801236
# 4          0; 0.1868063
#              ...
# 5651    4294; 0.4410511
# 5652    4295; 0.4410535
# 5653    4296; 0.4418299
# 5654    4296; 0.4412146
# 5655    4297; 0.4410169
# Name: 0, Length: 5656, dtype: object
